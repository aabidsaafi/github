# %%
import gmsh
import sys

# %% [markdown]
# # Adaptive Mesh Generation

# %%
gmsh.initialize()
gmsh.model.add("Fiber_Composite")

#2R<spacing to avoid overlap of fibers

L = 1.0     # Domain size
R = 0.05    # Fiber radius  
lc = 0.03   # Mesh resolution (Balance between accuracy and condition number)
occ = gmsh.model.occ
  

# Calculate max allowable radius to prevent touching each other or the wall
# R must be less than spacing/2
R = 0.035
# Create Geometry
square = occ.addRectangle(0, 0, 0, L, L) #Rectangle(x, y, z, width, height)
# Create multiple fibers in a grid pattern
fiber_list = []
n_fibers_x = 10
n_fibers_y = 10
spacing = L / n_fibers_x

for i in range(n_fibers_x): # Loop over number of fibers in x direction 
    for j in range(n_fibers_y): #for each x fiber, loop over number of fibers in y direction
                                    x_c = (i+0.5) * spacing #center of fiber in x direction. Note we add 0.5 to center to make sure its in middle of spacing. we don't want circle at edge of spacing
                                    y_c = (j+0.5) * spacing
                                    # Create disk and Both circle and square start from same plane z=0. it uses the center of the circle as the anchor point, but that center is calculated relative to the origin (0,0) of the square (Bottom-Left Corner) .
                                    c = occ.addDisk(x_c, y_c, 0, R, R) #Disk(x_center, y_center, z_center, radius_x, radius_y)  
                                    fiber_list.append((2, c))




# Fragment and Synchronize
# ov contains all resulting surfaces after the boolean operation
ov, ovv = occ.fragment([(2, square)], fiber_list) #Fragment the square with the circle {dim, tag}. Note ovv are separate entities
occ.synchronize()

#  Dynamically Identify Surfaces
#The problem is that after the fragmenting.Gmsh doesn't inherently know which ID belongs to the "Matrix" and which belongs to the "Fiber." It just sees two surfaces.
# We look for the surface whose center of mass is the center of the square. # 

fiber_surface = []
matrix_surface = []

for surface in gmsh.model.getEntities(2):
# Get mass properties (this returns [mass/area, x, y, z])
# For a 2D surface, 'mass' is actually the area.
    mass_center = occ.getCenterOfMass(surface[0], surface[1])

    # We use a tool to get the actual area
    # (Dimension 2, ID surface[1])
    mass_props = occ.getMass(surface[0], surface[1])
    area = mass_props 

    # Logic: If it's small, it's the fiber. If it's large, it's the matrix.
    expected_fiber_area = 3.14159 * (R**2)

    if abs(area - expected_fiber_area) < 1e-4:
        fiber_surface.append(surface[1])
        print(f"Surface {surface[1]} identified as FIBER (Area: {area:.4f})")
    else:
        matrix_surface.append(surface[1])
        print(f"Surface {surface[1]} identified as MATRIX (Area: {area:.4f})")

# Now we have the IDs for both surfaces.
#Assign Physical Groups for Material Domains to help solver recognize them
gmsh.model.addPhysicalGroup(2, fiber_surface, tag=1, name="Fiber_Domain")
gmsh.model.addPhysicalGroup(2, matrix_surface, tag=2, name="Matrix_Domain")

 #Identify and Tag Boundary Edges ---
left_edges = []
right_edges = []
top_edges = []
bottom_edges = []
fiber_interface = []
# Get all 1D entities (curves/lines)
for edge in gmsh.model.getEntities(1):
# Get the bounding box of the line [xmin, ymin, zmin, xmax, ymax, zmax]
    bounds = gmsh.model.getBoundingBox(edge[0], edge[1])
# Unpack bounds  
    xmin, ymin, xmax, ymax = bounds[0], bounds[1], bounds[3], bounds[4] #[xmin, ymin, zmin, xmax, ymax, zmax]

# Check position with a small tolerance (1e-6)
if abs(xmin) < 1e-6 and abs(xmax) < 1e-6:
    left_edges.append(edge[1])                       #append edge ID to left_edges
elif abs(xmin - L) < 1e-6 and abs(xmax - L) < 1e-6:
    right_edges.append(edge[1])                      #append edge ID to right_edges
elif abs(ymin) < 1e-6 and abs(ymax) < 1e-6:
    bottom_edges.append(edge[1])                     #append edge ID to bottom_edges
elif abs(ymin - L) < 1e-6 and abs(ymax - L) < 1e-6:
    top_edges.append(edge[1])                        #append edge ID to top_edges
else:
# If it's not an outer wall, it's the interface between fiber and matrix!
    fiber_interface.append(edge[1])

# Create Physical Group for the interface (Tag 20)
gmsh.model.addPhysicalGroup(1, fiber_interface, tag=20, name="Fiber_Interface")
# Create Physical Groups for the boundaries
gmsh.model.addPhysicalGroup(1, left_edges, tag=10, name="Left_Side") ## (dimension, list_of_ids, tag, name)
gmsh.model.addPhysicalGroup(1, right_edges, tag=11, name="Right_Side")
gmsh.model.addPhysicalGroup(1, top_edges, tag=12, name="Top_Side")
gmsh.model.addPhysicalGroup(1, bottom_edges, tag=13, name="Bottom_Side")

# gmsh.model.mesh.setSize(gmsh.model.getEntities(0), lc) #Set mesh size at all vertices (0D entities) smaller lc = finer mesh(so its saying keep the distance between any two triangles at corner points of geometry  smaller in other words make the mesh smaller)
# gmsh.model.mesh.generate(2) #Generate 2D mesh 2 is dimension


# Local Mesh Refinement (Fields)  

# FIELD 1: Distance - Calculates distance from every point to the fiber edges
f1 = gmsh.model.mesh.field.add("Distance")
gmsh.model.mesh.field.setNumbers(f1, "CurvesList", fiber_interface)

# FIELD 2: Threshold - Takes the distance and maps it to a mesh size
f2 = gmsh.model.mesh.field.add("Threshold")
gmsh.model.mesh.field.setNumber(f2, "InField", f1)      # Use the distance field as input
gmsh.model.mesh.field.setNumber(f2, "SizeMin", lc / 6)  # Mesh size AT the fiber edge (tiny;closer to fiber)
gmsh.model.mesh.field.setNumber(f2, "SizeMax", lc)      # Mesh size in the matrix (normal)
gmsh.model.mesh.field.setNumber(f2, "DistMin", 0.01)    # Range for SizeMin (all points closer than this distance get SizeMin)
gmsh.model.mesh.field.setNumber(f2, "DistMax", 0.15)    # Distance where it reaches SizeMax (all points farther than this distance get SizeMax)

# FIELD 3: Constant - This ensures the mesh stays small INSIDE the fiber surfaces
f3 = gmsh.model.mesh.field.add("Constant") 
gmsh.model.mesh.field.setNumbers(f3, "SurfacesList", fiber_surface) #F3 returns default mesh value if point is outside fibers 
gmsh.model.mesh.field.setNumber(f3, "VIn", lc / 6)      # Force this size inside the fibers

# FIELD 4: Min - Combines f2 (matrix transition) and f3 (fiber interior)
# It tells Gmsh: "At any point, use the SMALLEST size from either Field 2 or Field 3"
f_min = gmsh.model.mesh.field.add("Min")
gmsh.model.mesh.field.setNumbers(f_min, "FieldsList", [f2, f3])

# Activate the refinement using the combined logic
gmsh.model.mesh.field.setAsBackgroundMesh(f_min) #this combines both fields so that we have fine mesh near fiber edges and also fine mesh inside fibers. Check f2 and f3 for details. 

# Disable default settings that might override our fields
gmsh.option.setNumber("Mesh.MeshSizeFromPoints", 0)
gmsh.option.setNumber("Mesh.MeshSizeFromCurvature", 0)
gmsh.option.setNumber("Mesh.MeshSizeExtendFromBoundary", 0)

#  Generate
gmsh.model.mesh.generate(2)
gmsh.write("refined_composite_with_interior.msh")

if '-nopopup' not in sys.argv:
 gmsh.fltk.run()

gmsh.finalize()
# Out:
# Surface 2 identified as FIBER (Area: 0.0038)
# Surface 3 identified as FIBER (Area: 0.0038)
# Surface 4 identified as FIBER (Area: 0.0038)
# Surface 5 identified as FIBER (Area: 0.0038)
# Surface 6 identified as FIBER (Area: 0.0038)
# Surface 7 identified as FIBER (Area: 0.0038)
# Surface 8 identified as FIBER (Area: 0.0038)
# Surface 9 identified as FIBER (Area: 0.0038)
# Surface 10 identified as FIBER (Area: 0.0038)
# Surface 11 identified as FIBER (Area: 0.0038)
# Surface 12 identified as FIBER (Area: 0.0038)
# Surface 13 identified as FIBER (Area: 0.0038)
# Surface 14 identified as FIBER (Area: 0.0038)
# Surface 15 identified as FIBER (Area: 0.0038)
# Surface 16 identified as FIBER (Area: 0.0038)
# Surface 17 identified as FIBER (Area: 0.0038)
# Surface 18 identified as FIBER (Area: 0.0038)
# Surface 19 identified as FIBER (Area: 0.0038)
# Surface 20 identified as FIBER (Area: 0.0038)
# Surface 21 identified as FIBER (Area: 0.0038)
# Surface 22 identified as FIBER (Area: 0.0038)
# Surface 23 identified as FIBER (Area: 0.0038)
# Surface 24 identified as FIBER (Area: 0.0038)
# Surface 25 identified as FIBER (Area: 0.0038)
# Surface 26 identified as FIBER (Area: 0.0038)
# Surface 27 identified as FIBER (Area: 0.0038)
# Surface 28 identified as FIBER (Area: 0.0038)
# Surface 29 identified as FIBER (Area: 0.0038)
# Surface 30 identified as FIBER (Area: 0.0038)
# Surface 31 identified as FIBER (Area: 0.0038)
# Surface 32 identified as FIBER (Area: 0.0038)
# Surface 33 identified as FIBER (Area: 0.0038)
# Surface 34 identified as FIBER (Area: 0.0038)
# Surface 35 identified as FIBER (Area: 0.0038)
# Surface 36 identified as FIBER (Area: 0.0038)
# Surface 37 identified as FIBER (Area: 0.0038)
# Surface 38 identified as FIBER (Area: 0.0038)
# Surface 39 identified as FIBER (Area: 0.0038)
# Surface 40 identified as FIBER (Area: 0.0038)
# Surface 41 identified as FIBER (Area: 0.0038)
# Surface 42 identified as FIBER (Area: 0.0038)
# Surface 43 identified as FIBER (Area: 0.0038)
# Surface 44 identified as FIBER (Area: 0.0038)
# Surface 45 identified as FIBER (Area: 0.0038)
# Surface 46 identified as FIBER (Area: 0.0038)
# Surface 47 identified as FIBER (Area: 0.0038)
# Surface 48 identified as FIBER (Area: 0.0038)
# Surface 49 identified as FIBER (Area: 0.0038)
# Surface 50 identified as FIBER (Area: 0.0038)
# Surface 51 identified as FIBER (Area: 0.0038)
# Surface 52 identified as FIBER (Area: 0.0038)
# Surface 53 identified as FIBER (Area: 0.0038)
# Surface 54 identified as FIBER (Area: 0.0038)
# Surface 55 identified as FIBER (Area: 0.0038)
# Surface 56 identified as FIBER (Area: 0.0038)
# Surface 57 identified as FIBER (Area: 0.0038)
# Surface 58 identified as FIBER (Area: 0.0038)
# Surface 59 identified as FIBER (Area: 0.0038)
# Surface 60 identified as FIBER (Area: 0.0038)
# Surface 61 identified as FIBER (Area: 0.0038)
# Surface 62 identified as FIBER (Area: 0.0038)
# Surface 63 identified as FIBER (Area: 0.0038)
# Surface 64 identified as FIBER (Area: 0.0038)
# Surface 65 identified as FIBER (Area: 0.0038)
# Surface 66 identified as FIBER (Area: 0.0038)
# Surface 67 identified as FIBER (Area: 0.0038)
# Surface 68 identified as FIBER (Area: 0.0038)
# Surface 69 identified as FIBER (Area: 0.0038)
# Surface 70 identified as FIBER (Area: 0.0038)
# Surface 71 identified as FIBER (Area: 0.0038)
# Surface 72 identified as FIBER (Area: 0.0038)
# Surface 73 identified as FIBER (Area: 0.0038)
# Surface 74 identified as FIBER (Area: 0.0038)
# Surface 75 identified as FIBER (Area: 0.0038)
# Surface 76 identified as FIBER (Area: 0.0038)
# Surface 77 identified as FIBER (Area: 0.0038)
# Surface 78 identified as FIBER (Area: 0.0038)
# Surface 79 identified as FIBER (Area: 0.0038)
# Surface 80 identified as FIBER (Area: 0.0038)
# Surface 81 identified as FIBER (Area: 0.0038)
# Surface 82 identified as FIBER (Area: 0.0038)
# Surface 83 identified as FIBER (Area: 0.0038)
# Surface 84 identified as FIBER (Area: 0.0038)
# Surface 85 identified as FIBER (Area: 0.0038)
# Surface 86 identified as FIBER (Area: 0.0038)
# Surface 87 identified as FIBER (Area: 0.0038)
# Surface 88 identified as FIBER (Area: 0.0038)
# Surface 89 identified as FIBER (Area: 0.0038)
# Surface 90 identified as FIBER (Area: 0.0038)
# Surface 91 identified as FIBER (Area: 0.0038)
# Surface 92 identified as FIBER (Area: 0.0038)
# Surface 93 identified as FIBER (Area: 0.0038)
# Surface 94 identified as FIBER (Area: 0.0038)
# Surface 95 identified as FIBER (Area: 0.0038)
# Surface 96 identified as FIBER (Area: 0.0038)
# Surface 97 identified as FIBER (Area: 0.0038)
# Surface 98 identified as FIBER (Area: 0.0038)
# Surface 99 identified as FIBER (Area: 0.0038)
# Surface 100 identified as FIBER (Area: 0.0038)
# Surface 101 identified as FIBER (Area: 0.0038)
# Surface 102 identified as MATRIX (Area: 0.6152)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 10%] Meshing curve 3 (Line)
# Info    : [ 10%] Meshing curve 4 (Line)
# Info    : [ 10%] Meshing curve 5 (Ellipse)
# Info    : [ 10%] Meshing curve 6 (Ellipse)
# Info    : [ 10%] Meshing curve 7 (Ellipse)
# Info    : [ 10%] Meshing curve 8 (Ellipse)
# Info    : [ 10%] Meshing curve 9 (Ellipse)
# Info    : [ 10%] Meshing curve 10 (Ellipse)
# Info    : [ 10%] Meshing curve 11 (Ellipse)
# Info    : [ 20%] Meshing curve 12 (Ellipse)
# Info    : [ 20%] Meshing curve 13 (Ellipse)
# Info    : [ 20%] Meshing curve 14 (Ellipse)
# Info    : [ 20%] Meshing curve 15 (Ellipse)
# Info    : [ 20%] Meshing curve 16 (Ellipse)
# Info    : [ 20%] Meshing curve 17 (Ellipse)
# Info    : [ 20%] Meshing curve 18 (Ellipse)
# Info    : [ 20%] Meshing curve 19 (Ellipse)
# Info    : [ 20%] Meshing curve 20 (Ellipse)
# Info    : [ 20%] Meshing curve 21 (Ellipse)
# Info    : [ 30%] Meshing curve 22 (Ellipse)
# Info    : [ 30%] Meshing curve 23 (Ellipse)
# Info    : [ 30%] Meshing curve 24 (Ellipse)
# Info    : [ 30%] Meshing curve 25 (Ellipse)
# Info    : [ 30%] Meshing curve 26 (Ellipse)
# Info    : [ 30%] Meshing curve 27 (Ellipse)
# Info    : [ 30%] Meshing curve 28 (Ellipse)
# Info    : [ 30%] Meshing curve 29 (Ellipse)
# Info    : [ 30%] Meshing curve 30 (Ellipse)
# Info    : [ 30%] Meshing curve 31 (Ellipse)
# Info    : [ 30%] Meshing curve 32 (Ellipse)
# Info    : [ 40%] Meshing curve 33 (Ellipse)
# Info    : [ 40%] Meshing curve 34 (Ellipse)
# Info    : [ 40%] Meshing curve 35 (Ellipse)
# Info    : [ 40%] Meshing curve 36 (Ellipse)
# Info    : [ 40%] Meshing curve 37 (Ellipse)
# Info    : [ 40%] Meshing curve 38 (Ellipse)
# Info    : [ 40%] Meshing curve 39 (Ellipse)
# Info    : [ 40%] Meshing curve 40 (Ellipse)
# Info    : [ 40%] Meshing curve 41 (Ellipse)
# Info    : [ 40%] Meshing curve 42 (Ellipse)
# Info    : [ 50%] Meshing curve 43 (Ellipse)
# Info    : [ 50%] Meshing curve 44 (Ellipse)
# Info    : [ 50%] Meshing curve 45 (Ellipse)
# Info    : [ 50%] Meshing curve 46 (Ellipse)
# Info    : [ 50%] Meshing curve 47 (Ellipse)
# Info    : [ 50%] Meshing curve 48 (Ellipse)
# Info    : [ 50%] Meshing curve 49 (Ellipse)
# Info    : [ 50%] Meshing curve 50 (Ellipse)
# Info    : [ 50%] Meshing curve 51 (Ellipse)
# Info    : [ 50%] Meshing curve 52 (Ellipse)
# Info    : [ 60%] Meshing curve 53 (Ellipse)
# Info    : [ 60%] Meshing curve 54 (Ellipse)
# Info    : [ 60%] Meshing curve 55 (Ellipse)
# Info    : [ 60%] Meshing curve 56 (Ellipse)
# Info    : [ 60%] Meshing curve 57 (Ellipse)
# Info    : [ 60%] Meshing curve 58 (Ellipse)
# Info    : [ 60%] Meshing curve 59 (Ellipse)
# Info    : [ 60%] Meshing curve 60 (Ellipse)
# Info    : [ 60%] Meshing curve 61 (Ellipse)
# Info    : [ 60%] Meshing curve 62 (Ellipse)
# Info    : [ 60%] Meshing curve 63 (Ellipse)
# Info    : [ 70%] Meshing curve 64 (Ellipse)
# Info    : [ 70%] Meshing curve 65 (Ellipse)
# Info    : [ 70%] Meshing curve 66 (Ellipse)
# Info    : [ 70%] Meshing curve 67 (Ellipse)
# Info    : [ 70%] Meshing curve 68 (Ellipse)
# Info    : [ 70%] Meshing curve 69 (Ellipse)
# Info    : [ 70%] Meshing curve 70 (Ellipse)
# Info    : [ 70%] Meshing curve 71 (Ellipse)
# Info    : [ 70%] Meshing curve 72 (Ellipse)
# Info    : [ 70%] Meshing curve 73 (Ellipse)
# Info    : [ 80%] Meshing curve 74 (Ellipse)
# Info    : [ 80%] Meshing curve 75 (Ellipse)
# Info    : [ 80%] Meshing curve 76 (Ellipse)
# Info    : [ 80%] Meshing curve 77 (Ellipse)
# Info    : [ 80%] Meshing curve 78 (Ellipse)
# Info    : [ 80%] Meshing curve 79 (Ellipse)
# Info    : [ 80%] Meshing curve 80 (Ellipse)
# Info    : [ 80%] Meshing curve 81 (Ellipse)
# Info    : [ 80%] Meshing curve 82 (Ellipse)
# Info    : [ 80%] Meshing curve 83 (Ellipse)
# Info    : [ 80%] Meshing curve 84 (Ellipse)
# Info    : [ 90%] Meshing curve 85 (Ellipse)
# Info    : [ 90%] Meshing curve 86 (Ellipse)
# Info    : [ 90%] Meshing curve 87 (Ellipse)
# Info    : [ 90%] Meshing curve 88 (Ellipse)
# Info    : [ 90%] Meshing curve 89 (Ellipse)
# Info    : [ 90%] Meshing curve 90 (Ellipse)
# Info    : [ 90%] Meshing curve 91 (Ellipse)
# Info    : [ 90%] Meshing curve 92 (Ellipse)
# Info    : [ 90%] Meshing curve 93 (Ellipse)
# Info    : [ 90%] Meshing curve 94 (Ellipse)
# Info    : [100%] Meshing curve 95 (Ellipse)
# Info    : [100%] Meshing curve 96 (Ellipse)
# Info    : [100%] Meshing curve 97 (Ellipse)
# Info    : [100%] Meshing curve 98 (Ellipse)
# Info    : [100%] Meshing curve 99 (Ellipse)
# Info    : [100%] Meshing curve 100 (Ellipse)
# Info    : [100%] Meshing curve 101 (Ellipse)
# Info    : [100%] Meshing curve 102 (Ellipse)
# Info    : [100%] Meshing curve 103 (Ellipse)
# Info    : [100%] Meshing curve 104 (Ellipse)
# Info    : Done meshing 1D (Wall 0.0125323s, CPU 0.011813s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 7 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 8 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 9 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 10 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 11 (Plane, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 12 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 13 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 14 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 15 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 16 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 17 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 18 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 19 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 20 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 21 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 22 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 23 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 24 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 25 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 26 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 27 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 28 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 29 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 30 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 31 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 32 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 33 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 34 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 35 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 36 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 37 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 38 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 39 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 40 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 41 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 42 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 43 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 44 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 45 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 46 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 47 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 48 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 49 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 50 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 51 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 52 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 53 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 54 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 55 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 56 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 57 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 58 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 59 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 60 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 61 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 62 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 63 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 64 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 65 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 66 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 67 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 68 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 69 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 70 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 71 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 72 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 73 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 74 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 75 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 76 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 77 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 78 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 79 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 80 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 81 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 82 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 83 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 84 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 85 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 86 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 87 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 88 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 89 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 90 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 91 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 92 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 93 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 94 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 95 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 96 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 97 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 98 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 99 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 100 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 101 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 102 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.507873s, CPU 0.488462s)
# Info    : 23703 nodes 51908 elements
# Info    : Writing 'refined_composite_with_interior.msh'...
# Info    : Done writing 'refined_composite_with_interior.msh'
# -------------------------------------------------------
# Version       : 4.15.0
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 20251026
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen[contrib] Fltk Gmm[contrib] Hxt Jpeg Kbipack Lapack[petsc] LinuxJoystick MathEx[contrib] Med Mesh Metis[contrib] Mmg Mpeg Netgen Nii2mesh ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom PETSc Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR TinyXML2[contrib] Untangle Voro++[contrib] WinslowUntangler Zlib tinyobjloader
# FLTK version  : 1.3.11
# PETSc version : 3.14.4 (real arithmtic)
# OCC version   : 7.8.1
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
